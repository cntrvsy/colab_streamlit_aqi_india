# %% [markdown]
# <a href="https://colab.research.google.com/github/cntrvsy/colab/blob/main/st20343345_CMP7005_PRAC1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # INTRODUCTION
#
# **Let's start by loading in our data from the GitHub Repo**
#
# | No. | File Name                     | No. | File Name                     |
# |-----|-------------------------------|-----|-------------------------------|
# | 1   | Ahmedabad_data.csv            | 14  | Guwahati_data.csv             |
# | 2   | Aizawl_data.csv               | 15  | Hyderabad_data.csv            |
# | 3   | Amaravati_data.csv            | 16  | Jaipur_data.csv               |
# | 4   | Amritsar_data.csv             | 17  | Jorapokhar_data.csv           |
# | 5   | Bengaluru_data.csv            | 18  | Kochi_data.csv                |
# | 6   | Bhopal_data.csv               | 19  | Kolkata_data.csv              |
# | 7   | Brajrajnagar_data.csv         | 20  | Lucknow_data.csv              |
# | 8   | Chandigarh_data.csv           | 21  | Mumbai_data.csv               |
# | 9   | Chennai_data.csv              | 22  | Patna_data.csv                |
# | 10  | Coimbatore_data.csv           | 23  | Shillong_data.csv             |
# | 11  | Delhi_data.csv                | 24  | Talcher_data.csv              |
# | 12  | Ernakulam_data.csv            | 25  | Thiruvananthapuram_data.csv   |
# | 13  | Gurugram_data.csv             | 26  | Visakhapatnam_data.csv        |

# %%
import pandas as pd
import numpy as np

city_names = [
    'Ahmedabad', 'Aizawl', 'Amaravati', 'Amritsar', 'Bengaluru', 'Bhopal',
    'Brajrajnagar', 'Chandigarh', 'Chennai', 'Coimbatore', 'Delhi', 'Ernakulam',
    'Gurugram', 'Guwahati', 'Hyderabad', 'Jaipur', 'Jorapokhar', 'Kochi',
    'Kolkata', 'Lucknow', 'Mumbai', 'Patna', 'Shillong', 'Talcher',
    'Thiruvananthapuram', 'Visakhapatnam'
]

dataframes = {}
for city in city_names:
    url = f'https://raw.githubusercontent.com/cntrvsy/colab/main/{city}_data.csv'
    dataframes[city] = pd.read_csv(url, header=0)

# %% [markdown]
# #FUNDERMENTAL DATA UNDERSTANDING

# %%
# combine it into one df
combined_df = pd.concat(dataframes.values())
combined_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 29531 entries, 0 to 1461
# Data columns (total 16 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   City        29531 non-null  object
#  1   Date        29531 non-null  object
#  2   PM2.5       24933 non-null  float64
#  3   PM10        18391 non-null  float64
#  4   NO          25949 non-null  float64
#  5   NO2         25946 non-null  float64
#  6   NOx         25346 non-null  float64
#  7   NH3         19203 non-null  float64
#  8   CO          27472 non-null  float64
#  9   SO2         25677 non-null  float64
#  10  O3          25509 non-null  float64
#  11  Benzene     23908 non-null  float64
#  12  Toluene     21490 non-null  float64
#  13  Xylene      11422 non-null  float64
#  14  AQI         24850 non-null  float64
#  15  AQI_Bucket  24850 non-null  object
# dtypes: float64(13), object(3)
# memory usage: 3.8+ MB

# %%
combined_df.head(3)
# Out:
#         City        Date  PM2.5  PM10     NO    NO2    NOx  NH3     CO    SO2  \
# 0  Ahmedabad  01/01/2015    NaN   NaN   0.92  18.22  17.15  NaN   0.92  27.64
# 1  Ahmedabad  02/01/2015    NaN   NaN   0.97  15.69  16.46  NaN   0.97  24.55
# 2  Ahmedabad  03/01/2015    NaN   NaN  17.40  19.30  29.70  NaN  17.40  29.07
#
#        O3  Benzene  Toluene  Xylene  AQI AQI_Bucket
# 0  133.36     0.00     0.02    0.00  NaN        NaN
# 1   34.06     3.68     5.50    3.77  NaN        NaN
# 2   30.70     6.80    16.40    2.25  NaN        NaN

# %%
#How many rows and columns are in your merged dataset?
combined_df.shape
print(f'No of Rows: {combined_df.shape[0]}, No of Columns: {combined_df.shape[1]}')
# Out:
# No of Rows: 29531, No of Columns: 16

# %%
combined_df.columns
# Out:
# Index(['City', 'Date', 'PM2.5', 'PM10', 'NO', 'NO2', 'NOx', 'NH3', 'CO', 'SO2',
#        'O3', 'Benzene', 'Toluene', 'Xylene', 'AQI', 'AQI_Bucket'],
#       dtype='object')

# %%
combined_df.describe()
# add inference here so what each could tell us
# Out:
#               PM2.5          PM10            NO           NO2           NOx  \
# count  24933.000000  18391.000000  25949.000000  25946.000000  25346.000000
# mean      67.450578    118.127103     17.574730     28.560659     32.309123
# std       64.661449     90.605110     22.785846     24.474746     31.646011
# min        0.040000      0.010000      0.020000      0.010000      0.000000
# 25%       28.820000     56.255000      5.630000     11.750000     12.820000
# 50%       48.570000     95.680000      9.890000     21.690000     23.520000
# 75%       80.590000    149.745000     19.950000     37.620000     40.127500
# max      949.990000   1000.000000    390.680000    362.210000    467.630000
#
#                 NH3            CO           SO2            O3       Benzene  \
# count  19203.000000  27472.000000  25677.000000  25509.000000  23908.000000
# mean      23.483476      2.248598     14.531977     34.491430      3.280840
# std       25.684275      6.962884     18.133775     21.694928     15.811136
# min        0.010000      0.000000      0.010000      0.010000      0.000000
# 25%        8.580000      0.510000      5.670000     18.860000      0.120000
# 50%       15.850000      0.890000      9.160000     30.840000      1.070000
# 75%       30.020000      1.450000     15.220000     45.570000      3.080000
# max      352.890000    175.810000    193.860000    257.730000    455.030000
#
#             Toluene        Xylene           AQI
# count  21490.000000  11422.000000  24850.000000
# mean       8.700972      3.070128    166.463581
# std       19.969164      6.323247    140.696585
# min        0.000000      0.000000     13.000000
# 25%        0.600000      0.140000     81.000000
# 50%        2.970000      0.980000    118.000000
# 75%        9.150000      3.350000    208.000000
# max      454.850000    170.370000   2049.000000

# %%
#Which Pollutants are included, and which have the most missing data?
combined_df.isnull().sum()
# Out:
# City              0
# Date              0
# PM2.5          4598
# PM10          11140
# NO             3582
# NO2            3585
# NOx            4185
# NH3           10328
# CO             2059
# SO2            3854
# O3             4022
# Benzene        5623
# Toluene        8041
# Xylene        18109
# AQI            4681
# AQI_Bucket     4681
# dtype: int64

# %%
#How many unique cities are there?
combined_df['City'].nunique()
# Out:
# 26

# %%
def missing_values_table(combined_df):
    # Total missing values
    mis_val = combined_df.isnull().sum()

    # Percentage of missing values
    mis_val_percent = 100 * mis_val / len(combined_df)

    mis_val_table = pd.concat([mis_val, mis_val_percent], axis=1)

    mis_val_table = mis_val_table.rename(columns={0: 'Missing Values', 1: '% of Total Values'})

    # Sort the table by percentage of missing descending
    mis_val_table = mis_val_table.sort_values('% of Total Values', ascending=False)

    return mis_val_table

missing_values = missing_values_table(combined_df)
display(missing_values.style.background_gradient(cmap='Reds'))
# Out:
# <style type="text/css">
# #T_d862f_row0_col0, #T_d862f_row0_col1 {
#   background-color: #67000d;
#   color: #f1f1f1;
# }
# #T_d862f_row1_col0, #T_d862f_row1_col1 {
#   background-color: #f03f2e;
#   color: #f1f1f1;
# }
# #T_d862f_row2_col0, #T_d862f_row2_col1 {
#   background-color: #f44f39;
#   color: #f1f1f1;
# }
# #T_d862f_row3_col0, #T_d862f_row3_col1 {
#   background-color: #fb7c5c;
#   color: #f1f1f1;
# }
# #T_d862f_row4_col0, #T_d862f_row4_col1 {
#   background-color: #fca78b;
#   color: #000000;
# }
# #T_d862f_row5_col0, #T_d862f_row5_col1, #T_d862f_row6_col0, #T_d862f_row6_col1 {
#   background-color: #fcb89e;
#   color: #000000;
# }
# #T_d862f_row7_col0, #T_d862f_row7_col1 {
#   background-color: #fcb99f;
#   color: #000000;
# }
# #T_d862f_row8_col0, #T_d862f_row8_col1 {
#   background-color: #fcc1a8;
#   color: #000000;
# }
# #T_d862f_row9_col0, #T_d862f_row9_col1 {
#   background-color: #fcc4ad;
#   color: #000000;
# }
# #T_d862f_row10_col0, #T_d862f_row10_col1 {
#   background-color: #fdc6b0;
#   color: #000000;
# }
# #T_d862f_row11_col0, #T_d862f_row11_col1, #T_d862f_row12_col0, #T_d862f_row12_col1 {
#   background-color: #fdcbb6;
#   color: #000000;
# }
# #T_d862f_row13_col0, #T_d862f_row13_col1 {
#   background-color: #fee2d5;
#   color: #000000;
# }
# #T_d862f_row14_col0, #T_d862f_row14_col1, #T_d862f_row15_col0, #T_d862f_row15_col1 {
#   background-color: #fff5f0;
#   color: #000000;
# }
# </style>
# <table id="T_d862f" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d862f_level0_col0" class="col_heading level0 col0" >Missing Values</th>
#       <th id="T_d862f_level0_col1" class="col_heading level0 col1" >% of Total Values</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d862f_level0_row0" class="row_heading level0 row0" >Xylene</th>
#       <td id="T_d862f_row0_col0" class="data row0 col0" >18109</td>
#       <td id="T_d862f_row0_col1" class="data row0 col1" >61.322001</td>
#     </tr>
#     <tr>
#       <th id="T_d862f_level0_row1" class="row_heading level0 row1" >PM10</th>
#       <td id="T_d862f_row1_col0" class="data row1 col0" >11140</td>
#       <td id="T_d862f_row1_col1" class="data row1 col1" >37.723071</td>
#     </tr>
#     <tr>
#       <th id="T_d862f_level0_row2" class="row_heading level0 row2" >NH3</th>
#       <td id="T_d862f_row2_col0" class="data row2 col0" >10328</td>
#       <td id="T_d862f_row2_col1" class="data row2 col1" >34.973418</td>
#     </tr>
#     <tr>
#       <th id="T_d862f_level0_row3" class="row_heading level0 row3" >Toluene</th>
#       <td id="T_d862f_row3_col0" class="data row3 col0" >8041</td>
#       <td id="T_d862f_row3_col1" class="data row3 col1" >27.229014</td>
#     </tr>
#     <tr>
#       <th id="T_d862f_level0_row4" class="row_heading level0 row4" >Benzene</th>
#       <td id="T_d862f_row4_col0" class="data row4 col0" >5623</td>
#       <td id="T_d862f_row4_col1" class="data row4 col1" >19.041008</td>
#     </tr>
#     <tr>
#       <th id="T_d862f_level0_row5" class="row_heading level0 row5" >AQI</th>
#       <td id="T_d862f_row5_col0" class="data row5 col0" >4681</td>
#       <td id="T_d862f_row5_col1" class="data row5 col1" >15.851139</td>
#     </tr>
#     <tr>
#       <th id="T_d862f_level0_row6" class="row_heading level0 row6" >AQI_Bucket</th>
#       <td id="T_d862f_row6_col0" class="data row6 col0" >4681</td>
#       <td id="T_d862f_row6_col1" class="data row6 col1" >15.851139</td>
#     </tr>
#     <tr>
#       <th id="T_d862f_level0_row7" class="row_heading level0 row7" >PM2.5</th>
#       <td id="T_d862f_row7_col0" class="data row7 col0" >4598</td>
#       <td id="T_d862f_row7_col1" class="data row7 col1" >15.570079</td>
#     </tr>
#     <tr>
#       <th id="T_d862f_level0_row8" class="row_heading level0 row8" >NOx</th>
#       <td id="T_d862f_row8_col0" class="data row8 col0" >4185</td>
#       <td id="T_d862f_row8_col1" class="data row8 col1" >14.171549</td>
#     </tr>
#     <tr>
#       <th id="T_d862f_level0_row9" class="row_heading level0 row9" >O3</th>
#       <td id="T_d862f_row9_col0" class="data row9 col0" >4022</td>
#       <td id="T_d862f_row9_col1" class="data row9 col1" >13.619586</td>
#     </tr>
#     <tr>
#       <th id="T_d862f_level0_row10" class="row_heading level0 row10" >SO2</th>
#       <td id="T_d862f_row10_col0" class="data row10 col0" >3854</td>
#       <td id="T_d862f_row10_col1" class="data row10 col1" >13.050692</td>
#     </tr>
#     <tr>
#       <th id="T_d862f_level0_row11" class="row_heading level0 row11" >NO2</th>
#       <td id="T_d862f_row11_col0" class="data row11 col0" >3585</td>
#       <td id="T_d862f_row11_col1" class="data row11 col1" >12.139785</td>
#     </tr>
#     <tr>
#       <th id="T_d862f_level0_row12" class="row_heading level0 row12" >NO</th>
#       <td id="T_d862f_row12_col0" class="data row12 col0" >3582</td>
#       <td id="T_d862f_row12_col1" class="data row12 col1" >12.129626</td>
#     </tr>
#     <tr>
#       <th id="T_d862f_level0_row13" class="row_heading level0 row13" >CO</th>
#       <td id="T_d862f_row13_col0" class="data row13 col0" >2059</td>
#       <td id="T_d862f_row13_col1" class="data row13 col1" >6.972334</td>
#     </tr>
#     <tr>
#       <th id="T_d862f_level0_row14" class="row_heading level0 row14" >Date</th>
#       <td id="T_d862f_row14_col0" class="data row14 col0" >0</td>
#       <td id="T_d862f_row14_col1" class="data row14 col1" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_d862f_level0_row15" class="row_heading level0 row15" >City</th>
#       <td id="T_d862f_row15_col0" class="data row15 col0" >0</td>
#       <td id="T_d862f_row15_col1" class="data row15 col1" >0.000000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# #DATA CLEANING

# %%
#Convert Order Date to a proper datetime format.
combined_df['Date'] = pd.to_datetime(combined_df['Date'], format="mixed", errors="coerce")

# Xylene
xylene_median = combined_df['Xylene'].median()
combined_df['Xylene'] = combined_df['Xylene'].fillna(xylene_median)
print(f"Missing values in 'Xylene' column after median imputation: {combined_df['Xylene'].isnull().sum()}")

#PM10
pm10_median = combined_df['PM10'].median()
combined_df['PM10'] = combined_df['PM10'].fillna(pm10_median)
print(f"Missing values in 'PM10' column after median imputation: {combined_df['PM10'].isnull().sum()}")

#NH3
nh3_median = combined_df['NH3'].median()
combined_df['NH3'] = combined_df['NH3'].fillna(nh3_median)
print(f"Missing values in 'NH3' column after median imputation: {combined_df['NH3'].isnull().sum()}")
# Out:
# Missing values in 'Xylene' column after median imputation: 0
# Missing values in 'PM10' column after median imputation: 0
# Missing values in 'NH3' column after median imputation: 0

# %%
combined_df.isnull().sum()
# Out:
# City             0
# Date             0
# PM2.5         4598
# PM10             0
# NO            3582
# NO2           3585
# NOx           4185
# NH3              0
# CO            2059
# SO2           3854
# O3            4022
# Benzene       5623
# Toluene       8041
# Xylene           0
# AQI           4681
# AQI_Bucket    4681
# dtype: int64

# %%
import numpy as np
import pandas as pd

def aqi_to_bucket(aqi):
    if pd.isna(aqi):
        return np.nan
    aqi = float(aqi)
    if aqi <= 50:
        return "good"
    if aqi <= 100:
        return "satisfactory"
    if aqi <= 200:
        return "moderate"
    if aqi <= 300:
        return "poor"
    if aqi <= 400:
        return "very poor"
    return "severe"

# %%
combined_df['AQI_Bucket'] = combined_df['AQI'].apply(aqi_to_bucket)

# Display the first few rows to show the updated AQI_Bucket
display(combined_df[['AQI', 'AQI_Bucket']].head())
# Out:
#    AQI AQI_Bucket
# 0  NaN        NaN
# 1  NaN        NaN
# 2  NaN        NaN
# 3  NaN        NaN
# 4  NaN        NaN

# %% [markdown]
# #Inference - DATA CLEANING
#  - For most of the pollutant columns (PM2.5, NO, NO2, NOx, NH3, CO, SO2, O3, Benzene, Toluene, and AQI), the median is likely the most appropriate choice as Pollutant levels are rarely perfectly normally distributed and often have higher frequencies at lower concentrations with occasional high peaks.
#  -Mean wouldnt work as it is sensitive to extreme values in the dataset.

# %%
missing_values_after_aqi_bucket = missing_values_table(combined_df)
display(missing_values_after_aqi_bucket.style.background_gradient(cmap='Reds'))
# Out:
# <style type="text/css">
# #T_0cb32_row0_col0, #T_0cb32_row0_col1 {
#   background-color: #67000d;
#   color: #f1f1f1;
# }
# #T_0cb32_row1_col0, #T_0cb32_row1_col1 {
#   background-color: #d92523;
#   color: #f1f1f1;
# }
# #T_0cb32_row2_col0, #T_0cb32_row2_col1, #T_0cb32_row3_col0, #T_0cb32_row3_col1 {
#   background-color: #f34a36;
#   color: #f1f1f1;
# }
# #T_0cb32_row4_col0, #T_0cb32_row4_col1 {
#   background-color: #f44f39;
#   color: #f1f1f1;
# }
# #T_0cb32_row5_col0, #T_0cb32_row5_col1 {
#   background-color: #f96245;
#   color: #f1f1f1;
# }
# #T_0cb32_row6_col0, #T_0cb32_row6_col1 {
#   background-color: #fb694a;
#   color: #f1f1f1;
# }
# #T_0cb32_row7_col0, #T_0cb32_row7_col1 {
#   background-color: #fb7151;
#   color: #f1f1f1;
# }
# #T_0cb32_row8_col0, #T_0cb32_row8_col1, #T_0cb32_row9_col0, #T_0cb32_row9_col1 {
#   background-color: #fb7b5b;
#   color: #f1f1f1;
# }
# #T_0cb32_row10_col0, #T_0cb32_row10_col1 {
#   background-color: #fcb99f;
#   color: #000000;
# }
# #T_0cb32_row11_col0, #T_0cb32_row11_col1, #T_0cb32_row12_col0, #T_0cb32_row12_col1, #T_0cb32_row13_col0, #T_0cb32_row13_col1, #T_0cb32_row14_col0, #T_0cb32_row14_col1, #T_0cb32_row15_col0, #T_0cb32_row15_col1 {
#   background-color: #fff5f0;
#   color: #000000;
# }
# </style>
# <table id="T_0cb32" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0cb32_level0_col0" class="col_heading level0 col0" >Missing Values</th>
#       <th id="T_0cb32_level0_col1" class="col_heading level0 col1" >% of Total Values</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0cb32_level0_row0" class="row_heading level0 row0" >Toluene</th>
#       <td id="T_0cb32_row0_col0" class="data row0 col0" >8041</td>
#       <td id="T_0cb32_row0_col1" class="data row0 col1" >27.229014</td>
#     </tr>
#     <tr>
#       <th id="T_0cb32_level0_row1" class="row_heading level0 row1" >Benzene</th>
#       <td id="T_0cb32_row1_col0" class="data row1 col0" >5623</td>
#       <td id="T_0cb32_row1_col1" class="data row1 col1" >19.041008</td>
#     </tr>
#     <tr>
#       <th id="T_0cb32_level0_row2" class="row_heading level0 row2" >AQI_Bucket</th>
#       <td id="T_0cb32_row2_col0" class="data row2 col0" >4681</td>
#       <td id="T_0cb32_row2_col1" class="data row2 col1" >15.851139</td>
#     </tr>
#     <tr>
#       <th id="T_0cb32_level0_row3" class="row_heading level0 row3" >AQI</th>
#       <td id="T_0cb32_row3_col0" class="data row3 col0" >4681</td>
#       <td id="T_0cb32_row3_col1" class="data row3 col1" >15.851139</td>
#     </tr>
#     <tr>
#       <th id="T_0cb32_level0_row4" class="row_heading level0 row4" >PM2.5</th>
#       <td id="T_0cb32_row4_col0" class="data row4 col0" >4598</td>
#       <td id="T_0cb32_row4_col1" class="data row4 col1" >15.570079</td>
#     </tr>
#     <tr>
#       <th id="T_0cb32_level0_row5" class="row_heading level0 row5" >NOx</th>
#       <td id="T_0cb32_row5_col0" class="data row5 col0" >4185</td>
#       <td id="T_0cb32_row5_col1" class="data row5 col1" >14.171549</td>
#     </tr>
#     <tr>
#       <th id="T_0cb32_level0_row6" class="row_heading level0 row6" >O3</th>
#       <td id="T_0cb32_row6_col0" class="data row6 col0" >4022</td>
#       <td id="T_0cb32_row6_col1" class="data row6 col1" >13.619586</td>
#     </tr>
#     <tr>
#       <th id="T_0cb32_level0_row7" class="row_heading level0 row7" >SO2</th>
#       <td id="T_0cb32_row7_col0" class="data row7 col0" >3854</td>
#       <td id="T_0cb32_row7_col1" class="data row7 col1" >13.050692</td>
#     </tr>
#     <tr>
#       <th id="T_0cb32_level0_row8" class="row_heading level0 row8" >NO2</th>
#       <td id="T_0cb32_row8_col0" class="data row8 col0" >3585</td>
#       <td id="T_0cb32_row8_col1" class="data row8 col1" >12.139785</td>
#     </tr>
#     <tr>
#       <th id="T_0cb32_level0_row9" class="row_heading level0 row9" >NO</th>
#       <td id="T_0cb32_row9_col0" class="data row9 col0" >3582</td>
#       <td id="T_0cb32_row9_col1" class="data row9 col1" >12.129626</td>
#     </tr>
#     <tr>
#       <th id="T_0cb32_level0_row10" class="row_heading level0 row10" >CO</th>
#       <td id="T_0cb32_row10_col0" class="data row10 col0" >2059</td>
#       <td id="T_0cb32_row10_col1" class="data row10 col1" >6.972334</td>
#     </tr>
#     <tr>
#       <th id="T_0cb32_level0_row11" class="row_heading level0 row11" >PM10</th>
#       <td id="T_0cb32_row11_col0" class="data row11 col0" >0</td>
#       <td id="T_0cb32_row11_col1" class="data row11 col1" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_0cb32_level0_row12" class="row_heading level0 row12" >NH3</th>
#       <td id="T_0cb32_row12_col0" class="data row12 col0" >0</td>
#       <td id="T_0cb32_row12_col1" class="data row12 col1" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_0cb32_level0_row13" class="row_heading level0 row13" >City</th>
#       <td id="T_0cb32_row13_col0" class="data row13 col0" >0</td>
#       <td id="T_0cb32_row13_col1" class="data row13 col1" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_0cb32_level0_row14" class="row_heading level0 row14" >Date</th>
#       <td id="T_0cb32_row14_col0" class="data row14 col0" >0</td>
#       <td id="T_0cb32_row14_col1" class="data row14 col1" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_0cb32_level0_row15" class="row_heading level0 row15" >Xylene</th>
#       <td id="T_0cb32_row15_col0" class="data row15 col0" >0</td>
#       <td id="T_0cb32_row15_col1" class="data row15 col1" >0.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Out:
# Missing values in 'Xylene' column after median imputation: 0

# %% [markdown]
# ### Handling Missing Values in PM10
#
# Following the strategy used for Xylene, we will now impute the missing values in the 'PM10' column. The median value will be used for imputation to maintain data integrity and robustness against potential outliers in pollutant measurements.

# %%
pm10_median = combined_df['PM10'].median()
combined_df['PM10'] = combined_df['PM10'].fillna(pm10_median)
print(f"Missing values in 'PM10' column after median imputation: {combined_df['PM10'].isnull().sum()}")
# Out:
# Missing values in 'PM10' column after median imputation: 0
